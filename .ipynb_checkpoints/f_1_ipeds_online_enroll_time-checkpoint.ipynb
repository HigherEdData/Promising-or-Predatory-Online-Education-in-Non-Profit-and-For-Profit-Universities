// %% [markdown]
// ## Promising or Predatory? Online Education in Non-Profit and For-Profit Universities
// ### By Christian Michael Smith, Amber D. Villalobos (equal authors), Laura T. Hamilton, and Charlie Eaton
//
// ### Code by Charlie Eaton and Christian Smith
//
// ### Estimation for Tables 3 and 5

// %%
ssc install blindschemes
// Out:
// checking blindschemes consistency and verifying not already installed...
// all files already exist and are up to date.

// %% [markdown]
// ### The following 5 code cells change the .stata_kernel.conf configuration file so that figures can be rendered within the NoteBook as png. This is necessary on Macs and Linux operating systems (but not Windows) for the Notebook to display figures on Github. Restart your kernel after running these 4 cells. For more details, see: https://github.com/kylebarron/stata_kernel/issues/382

// %%
%set execution_mode automation --permanently

// %%
%set graph_format png --permanently

// %%
%set graph_svg_redundancy False --permanently

// %%
%set graph_png_redundancy True --permanently

// %%
%set graph_scale 2 --permanently

// %%
use data/hdefa_dist20122019.dta, clear

// %%
qui {
drop if control<1
replace control=4 if iclevel>1 //Note that this includes <2yr institutions, and does not differentiate by for-profit/public status
collapse (sum) efdeexcu, by(year control)
reshape wide efdeexcu, i(year) j(control)
label var efdeexcu4 "community     "
label var efdeexcu3 "for-profit    "
label var efdeexcu2 "nonprofit (private)"
label var efdeexcu1 "nonprofit (public)"  
}

// %%
tw (connect efdeexcu3 efdeexcu2 efdeexcu1 year if year>2011 & year<2020, sort ///
legend(pos(6) size(small) order(1 4 2 3)) xlabel(2011(2)2020, ang(45) labsize(medium)) ///
ytitle("undergraduate online enrollment" " " " " "  ", size(medium)) ylabel(, format(%10.0fc) labsize(medium)) ///
xtitle("")  note("") scheme(plotplain))
// Out:
// This front-end cannot display the desired image type.

// %%
%head
// Out:
//      +--------------------------------------------------+
//      | year   efdeex~1   efdeex~2   efdeex~3   efdeex~4 |
//      |--------------------------------------------------|
//   1. | 2012     367181     266205     676688     682093 |
//   2. | 2013     399190     314830     615405     686351 |
//   3. | 2014     445836     370563     595294     713682 |
//   4. | 2015     471772     407020     518179     732003 |
//   5. | 2016     545877     425027     472255     739950 |
//      |--------------------------------------------------|
//   6. | 2017     590853     454624     434145     777954 |
//   7. | 2018     669682     477036     397440     808096 |
//   8. | 2019     722668     492231     412199     845392 |
//      +--------------------------------------------------+

// %%
outsheet using data/t_exclusively_online_undergrads_sector.csv, comma replace

// %% [markdown]
// ### The following 4 code cells return the .stata_kernel.conf configuration file to "Console" mode which runs multiple Notebooks at a time, and runs them faster than "Automation" code. Restart your kernel after running these 4 cells. For more details, see: https://github.com/kylebarron/stata_kernel/issues/382

// %%
%set execution_mode console --permanently

// %%
%set graph_format svg --permanently

// %%
%set graph_svg_redundancy True --permanently

// %%
%set graph_png_redundancy False --permanently

// %%
%set graph_scale 2 --permanently
